# %% [markdown]
# ## Cities Data Dataframe

# %%
# Dependencies and Setup
import pandas as pd

# Study data files
cities_data_path = "Resources/cities.csv"


# Read the cities data
cities_data = pd.read_csv(cities_data_path)


# Display the data table for preview
cities_data.head()
# Out:
#    City_ID           City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0   Port Hedland          90      AU  10/29/2020        93  59.70
# 1        1    New Norfolk          20      AU  10/29/2020        30  33.28
# 2        2      Taolanaro          98      MG  10/29/2020        74   5.89
# 3        3  Mount Gambier          63      AU  10/29/2020        76   3.07
# 4        4      Mahebourg         100      MU  10/29/2020        85  63.29
#
#       Lng  Max Temp  Wind Speed
# 0   30.79     45.00        4.47
# 1  134.15     68.00        3.36
# 2   95.32     82.31       10.65
# 3  172.79     82.58       19.42
# 4   18.72     33.80        2.24

# %%
cities_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1114 entries, 0 to 1113
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City_ID     1114 non-null   int64
#  1   City        1114 non-null   object
#  2   Cloudiness  1114 non-null   int64
#  3   Country     1105 non-null   object
#  4   Date        1114 non-null   object
#  5   Humidity    1114 non-null   int64
#  6   Lat         1114 non-null   float64
#  7   Lng         1114 non-null   float64
#  8   Max Temp    1114 non-null   float64
#  9   Wind Speed  1114 non-null   float64
# dtypes: float64(4), int64(3), object(3)
# memory usage: 87.2+ KB

# %%
# Convert to html
print(cities_data.to_html(index=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>City_ID</th>
#       <th>City</th>
#       <th>Cloudiness</th>
#       <th>Country</th>
#       <th>Date</th>
#       <th>Humidity</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Wind Speed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>Port Hedland</td>
#       <td>90</td>
#       <td>AU</td>
#       <td>10/29/2020</td>
#       <td>93</td>
#       <td>59.70</td>
#       <td>30.79</td>
#       <td>45.00</td>
#       <td>4.47</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>New Norfolk</td>
#       <td>20</td>
#       <td>AU</td>
#       <td>10/29/2020</td>
#       <td>30</td>
#       <td>33.28</td>
#       <td>134.15</td>
#       <td>68.00</td>
#       <td>3.36</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>Taolanaro</td>
#       <td>98</td>
#       <td>MG</td>
#       <td>10/29/2020</td>
# ...
